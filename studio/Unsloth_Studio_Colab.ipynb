# %% [markdown]
# <a href="https://colab.research.google.com/github/accessdenied12/cautious-lamp/blob/master/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Unsloth Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 3737, done.
# remote: Counting objects: 100% (3737/3737), done.
# remote: Compressing objects: 100% (3541/3541), done.
# remote: Total 3737 (delta 219), reused 1896 (delta 161), pack-reused 0 (from 0)
# Receiving objects: 100% (3737/3737), 48.40 MiB | 21.93 MiB/s, done.
# Resolving deltas: 100% (219/219), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  installing isolated Node (system Node/npm left untouched)...
#   node           v24.18.0 | npm 11.16.0 (isolated)
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Unsloth backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/16  base packages
#   deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [=======-------------]  6/16  dependency overrides
#                  torch 2.11.0+cu128 detected -- installing torchao==0.17.0
#   deps           [====================] 16/16  torch final (cuda)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b10360-mix-87da1a2 (tag b10360)
#   whisper.cpp    prebuilt installed
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start

# On Colab, start() auto-opens a Cloudflare link and prints admin login credentials.
# Use the Cloudflare link above the ready card to open Studio (in-cell iframes often stay blank).
start()

# To skip the Cloudflare tunnel and try the in-notebook proxy iframe only:
# start(cloudflare=False)
# Out:
# 2026-08-12 03:54:21 [info     ] 🦥 Starting Unsloth Studio...
# {"timestamp": "2026-08-12T03:54:28.193084Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-08-12T03:54:28.219134Z", "level": "info", "event": "   Starting server..."}
# {"timestamp": "2026-08-12T03:54:28.220027Z", "level": "info", "event": "run_server startup begin api_only=False host=0.0.0.0 port=8888"}
# {"timestamp": "2026-08-12T03:54:28.260853Z", "level": "info", "event": "Imported FastAPI app in 0.0ms"}
# {"timestamp": "2026-08-12T03:54:28.265617Z", "level": "info", "event": "Ensured Unsloth directories in 45.6ms"}
# {"timestamp": "2026-08-12T03:54:28.323413Z", "level": "info", "event": "run_server pre-uvicorn setup completed in 103.4ms"}
# INFO:     Started server process [1154]
# INFO:     Waiting for application startup.
# {"timestamp": "2026-08-12T03:54:28.490052Z", "level": "info", "event": "Removing unsloth compiled cache: /root/.unsloth/studio/compiled_cache"}
# {"timestamp": "2026-08-12T03:54:28.859539Z", "level": "info", "event": "lifespan pre-auth setup completed in 370.1ms"}
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Unsloth UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-08-12T03:54:29.011449Z", "level": "info", "event": "lifespan startup completed in 522.0ms"}
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://35.231.229.242:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# {"timestamp": "2026-08-12T03:54:29.032044Z", "level": "info", "event": "Uvicorn startup hook completed in 812.0ms"}
# {"timestamp": "2026-08-12T03:54:29.033329Z", "level": "info", "event": "run_server uvicorn ready after 813.3ms"}
# {"timestamp": "2026-08-12T03:54:29.712304Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-08-12T03:54:31.228742Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1507.77}
# Hardware detected: CUDA -- Tesla T4
# {"timestamp": "2026-08-12T03:54:32.058717Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-08-12T03:54:43.204078Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.78}
# {"timestamp": "2026-08-12T03:54:45.539380Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-use1c2-kdoqa7qfx9vy-c.us-east1-2.prod.colab.dev"}
# {"timestamp": "2026-08-12T03:54:45.540283Z", "level": "info", "event": "\ud83d\udd17 Shareable Cloudflare link: https://perry-necessarily-recovery-adipex.trycloudflare.com"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Shareable Unsloth Link is Ready!
#         </h2>
#         <a href="https://perry-necessarily-recovery-adipex.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px; cursor: pointer;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             This Cloudflare HTTPS link works from any device, so you can share it with anyone.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             🔗 <a href="https://perry-necessarily-recovery-adipex.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#                   style="color: #000000; text-decoration: underline; cursor: pointer;">https://perry-necessarily-recovery-adipex.trycloudflare.com</a>
#         </p>
#         <p style="color: #000000; margin: 16px 0 0 0; font-size: 20px; font-weight: 800;">
#             Password
#         </p>
#         <p style="margin: 6px 0 0 0;"><code style="display: inline-block; font-size: 24px;
#             font-weight: 800; text-decoration: underline; background: #f3f3f3;
#             padding: 4px 10px; border-radius: 6px;">AlibiShakingMoonlightExterior</code></p>
#         <p style="color: #666666; margin: 6px 0 0 0; font-size: 12px;">
#             Log in as <code>unsloth</code> with this password. Shown only in your
#             notebook session, and never included in the shared link.
#         </p>
#     </div>
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# {"timestamp": "2026-08-12T03:54:54.216463Z", "level": "info", "event": "torch warm finished in 25209.1ms"}
# {"timestamp": "2026-08-12T03:55:05.568174Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
